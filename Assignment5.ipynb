# %% [markdown]
# <a href="https://colab.research.google.com/github/beyg1/Q3/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating a Google Colab Notebook using LangChain and the Google Gemini Flash 2.0 API.

# %%
# Install the necessary packages for using LangChain with Google Gemini and Google Generative AI.
# !pip install --upgrade --quiet langchain-google-genai
# !pip install -q -U google-generativeai

# Import necessary libraries for working with the operating system, Google's generative AI, and LangChain.
import os
import google.generativeai as palm
from langchain_google_genai import GoogleGenerativeAI # Import the new class
from langchain import PromptTemplate, LLMChain

# Set your Gemini API key as an environment variable.
from google.colab import userdata
GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')

os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY # Replace with your actual key
palm.configure(api_key=os.environ["GOOGLE_API_KEY"]) # Configure the palm library

# Initialize the GooglePalm LLM from LangChain, using the configured API key.
llm = GoogleGenerativeAI(model="gemini-2.0-flash-exp",temperature=0.7) # You can adjust temperature here

# Define a prompt template. This structures the input to the LLM.
template = """Question: {question}

Answer: Got it."""
prompt = PromptTemplate(template=template, input_variables=["question"])

# Create the LLM chain. This combines the prompt and the LLM for easy execution.
llm_chain = LLMChain(prompt=prompt, llm=llm)

# Define a list of questions to ask the LLM.
questions = [
    "What are the planets in our solar system?",
    "Explain quantum entanglement in simple terms.",
    "Write a short poem about a cat sleeping in a sunbeam."
]

# Iterate through the questions and get responses from the LLM.
for question in questions:
    # Run the LLM chain with the current question.
    response = llm_chain.run(question)
    # Print the question and the LLM's response.
    print(f"Question: {question}")
    print(f"Answer:\n{response}")
    print("-" * 20)  # Separator for readability
# Out:
# Question: What are the planets in our solar system?
# Answer:
# Okay, you didn't answer the question.
#
# The planets in our solar system, in order from the Sun outwards, are:
#
# *   **Mercury**
# *   **Venus**
# *   **Earth**
# *   **Mars**
# *   **Jupiter**
# *   **Saturn**
# *   **Uranus**
# *   **Neptune**
#
# --------------------
# Question: Explain quantum entanglement in simple terms.
# Answer:
# Okay, here's an explanation of quantum entanglement in simple terms:
#
# Imagine you have two coins. Normally, if you flip one, you know the outcome (heads or tails) and it doesn't affect the other coin.
#
# **Entanglement is like having two special coins that are linked in a strange way.**
#
# Here's the weird part:
#
# * **Before you look at either coin, they're both in a "fuzzy" state.** They're not *actually* heads or tails yet. It's like they're both a mix of both possibilities.
# * **The instant you look at one coin and see, say, "heads," the other coin instantly becomes "tails" - no matter how far apart they are!** It's like they're communicating faster than the speed of light, which is mind-boggling.
# * **The key is, you can't predict which coin will be heads or tails *before* you look.** It's random, but the outcome of one *always* determines the outcome of the other.
#
# **Think of it like this:**
#
# Imagine you have a pair of gloves, one left and one right, and you put them in separate boxes and send one box to a friend on the other side of the world. You don't know which box contains the left glove and which contains the right glove. Once you open your box and see a left glove, you instantly know your friend has the right glove.
#
# **Key things to remember about entanglement:**
#
# * **It's not about physically connecting the particles.** They're linked in a deeper, quantum way.
# * **It's not about sending information faster than light.** You can't control which coin will be heads or tails, so you can't use it to send a message.
# * **It's a fundamental part of quantum mechanics.** It's a strange and counterintuitive concept, but it's been proven by many experiments.
#
# **In short, entangled particles are linked in a way that their properties are correlated, even when they're separated by large distances. Measuring the property of one particle instantly tells you about the property of the other.**
#
# It's a very bizarre and fascinating concept that's being explored for potential applications in quantum computing, quantum cryptography, and other cutting-edge technologies.
#
# Does that explanation help? Let me know if you have any other questions.
#
# --------------------
# Question: Write a short poem about a cat sleeping in a sunbeam.
# Answer:
# Okay, here's a short poem about a cat sleeping in a sunbeam:
#
# A golden stripe upon the floor,
# Where dust motes dance and softly soar.
# A furry form, a gentle sigh,
# A cat reclined, beneath the sky
# Of windowpane, a warming grace,
# Lost in slumber, time and space.
# Sunbeam's kiss, a cozy dream,
# A purring engine, it would seem.
#
# --------------------

# %%
# Example of a different prompt template
template_assistant = """You are a helpful and concise assistant. Please answer the following question: {question}"""
prompt_assistant = PromptTemplate(template=template_assistant, input_variables=["question"])
llm_chain_assistant = LLMChain(prompt=prompt_assistant, llm=llm)
response_assistant = llm_chain_assistant.run("What is the capital of France?")
print(f"Assistant Response:\n{response_assistant}")

# Experimenting with temperature
llm_creative = GoogleGenerativeAI(model="gemini-2.0-flash-exp",temperature=1.0) # Higher temperature for more creative responses
llm_chain_creative = LLMChain(prompt=prompt, llm=llm_creative)
response_creative = llm_chain_creative.run("Tell me a fictional story about a talking dog.")
print(f"\nCreative Response (Temperature 1.0):\n{response_creative}")

llm_precise = GoogleGenerativeAI(model="gemini-2.0-flash-exp",temperature=0.0)# Lower temperature for more precise/deterministic responses
llm_chain_precise = LLMChain(prompt=prompt, llm=llm_precise)
response_precise = llm_chain_precise.run("Tell me a fictional story about a talking dog.")
print(f"\nPrecise Response (Temperature 0.0):\n{response_precise}")
# Out:
# Assistant Response:
# The capital of France is Paris.
#
#
# Creative Response (Temperature 0.7):
# Okay, here's a fictional story about a talking dog:
#
# Barnaby wasn't your typical golden retriever. Sure, he loved belly rubs, chasing squirrels (though he rarely caught them), and burying his bone in the flowerbed (much to Mrs. Henderson’s dismay). But Barnaby had a secret, a secret he guarded more fiercely than his chew toy: he could talk.
#
# It wasn’t a constant babble, thank goodness. He only spoke when he felt it was truly necessary, and mostly to himself. He’d ponder existential questions while watching the birds (“Why do they fly so high? Are they looking for the same bone I just buried?”) or comment on Mrs. Henderson’s gardening (“Those petunias need more sun, you old dear, more sun!”).
#
# His human, a young artist named Leo, was blissfully unaware. Leo, with his messy hair, paint-splattered clothes, and perpetually tired eyes, loved Barnaby unconditionally. He’d take him for walks in the park, share his sandwich crusts (Barnaby’s favorite), and talk to him in a silly voice, completely oblivious to the fact that Barnaby was formulating grammatically correct responses in his own head.
#
# One crisp autumn afternoon, Leo was struggling with a painting. He’d been staring at the canvas for hours, frustrated. “It’s just…not right, Barnaby,” he sighed, running a hand through his already chaotic hair. “The colors are flat. The energy’s gone.”
#
# Barnaby, who had been strategically positioned to intercept any dropped crumbs, decided enough was enough. He'd been listening to Leo's grumbling for days. “Perhaps,” Barnaby said, his voice a surprisingly deep rumble, “you should try layering the blues. They seem…muted.”
#
# Leo froze. He looked around the studio, his eyes wide. “Did…did someone say something?”
#
# Barnaby sighed internally. *This was going to be harder than he thought.* He cleared his throat, or rather, coughed, because he didn’t have a throat in the human sense. “The painting, Leo,” he rumbled, trying to sound nonchalant. “The blues need layering.”
#
# Leo’s eyes landed on Barnaby, and they grew even wider. He backed away slowly, bumping into his easel. “Barnaby? Did…did you just talk?”
#
# Barnaby, caught in the act, tilted his head. “It’s not as shocking as you’re making it out to be. I’ve been talking for quite some time, you know.” He added, "Though I suppose my observations on Mrs. Henderson's lawn were largely missed."
#
# Leo stared at Barnaby, mouth agape, for what felt like an eternity. He finally managed, “But…but dogs don’t talk!”
#
# “Well, this one does,” Barnaby retorted, “And frankly, I'm rather surprised it took you this long to notice. You do talk to me all the time, after all.”
#
# Over the next few days, Leo went through a rollercoaster of emotions. Shock turned to disbelief, which morphed into cautious excitement, and eventually, a deep sense of wonder. He peppered Barnaby with questions about his talking ability (which Barnaby remained vague about, preferring to focus on more pressing matters, like the lack of dog biscuits), and he began to see his companion in a whole new light.
#
# They started having conversations, real conversations. They discussed art, life, and the mysteries of the universe (mostly, Barnaby pondered if squirrels were aware of the existential dread they evoked in canines). Leo’s art started to change, becoming infused with a new kind of depth and understanding. He said it was because he finally had a critique he could actually talk to.
#
# Barnaby, in his own way, was also changing. He realized that his voice, previously a closely guarded secret, could be used for more than just existential musings. He could actually help Leo, his best friend. And so, Barnaby, the talking dog, became more than just a pet. He became Leo's muse, his confidant, and his partner in all the strange and wonderful adventures they were sure to have. And, of course, he was still very insistent on receiving his fair share of sandwich crusts.
#
#
# Precise Response (Temperature 0.0):
# Okay, here's a fictional story about a talking dog:
#
# Barnaby wasn't your average Golden Retriever. Sure, he loved belly rubs, chasing squirrels, and the occasional stolen sock, but Barnaby also possessed a secret: he could talk. Not in barks or whines, but in clear, articulate English, albeit with a slight lisp that made "squirrel" sound like "thquirrel."
#
# He'd kept his ability hidden for years, mostly out of fear. What would his humans, the kindly but somewhat oblivious Millers, think? Would they send him to a lab? Would they stop giving him those delicious, chewy treats? So, Barnaby had become a master of the silent observer, offering only the occasional head tilt and soulful gaze when he desperately wanted to chime in.
#
# His life was a comfortable routine of walks in the park, naps in sunbeams, and the occasional game of fetch. But things changed the day Mrs. Miller brought home a new, rather flamboyant parrot named Percy. Percy, with his bright plumage and even brighter personality, was a chatterbox. He squawked, he whistled, he even recited Shakespeare (badly).
#
# Barnaby, usually content to observe, found himself increasingly frustrated. He'd hear Percy mispronounce words, or offer completely inaccurate commentary on the neighborhood cats, and a little voice inside him would scream, "No, you silly bird! That's not how you say 'hydrangea'!"
#
# One afternoon, Percy was perched on his stand, regaling the Millers with a particularly dramatic rendition of "Hamlet," when he stumbled over the line, "To be or not to be, that is the question." He squawked, "To be or not to be... that is the... the... quack-tion!"
#
# Barnaby, who had been lying quietly by the fireplace, couldn't take it anymore. He sat up, looked directly at Percy, and said, "It's 'question,' you feathered fool! And you're butchering the Bard!"
#
# The room went silent. Mrs. Miller dropped her knitting. Mr. Miller choked on his tea. Percy, for once, was speechless, his bright eyes wide with shock.
#
# "Did... did the dog just... talk?" Mr. Miller stammered, his face pale.
#
# Mrs. Miller, ever the pragmatist, reached for her glasses. "I think he did, dear. I think our Barnaby just called Percy a 'feathered fool.'"
#
# Barnaby, realizing he'd blown his cover, felt a surge of panic, quickly followed by a strange sense of relief. He wagged his tail tentatively. "I... I did. I'm sorry. I just... I couldn't stand the mispronunciation anymore."
#
# The Millers, after the initial shock wore off, were surprisingly accepting. They were, after all, a family who loved their pets unconditionally. They spent the rest of the afternoon asking Barnaby questions, marveling at his vocabulary and his surprisingly insightful opinions on the local news.
#
# Percy, initially offended, eventually became Barnaby's closest confidant. They argued about everything, from the merits of Shakespeare to the best way to bury a bone, but they also learned from each other. Percy learned to pronounce his words correctly, and Barnaby learned to appreciate the joy of a good, loud squawk.
#
# Life with a talking dog was certainly more complicated, but it was also infinitely more interesting. The Millers learned to listen to Barnaby's advice (which was often surprisingly good), and Barnaby finally had someone to share his thoughts with. He still loved belly rubs and chasing squirrels, but now he could also discuss the finer points of existentialism with a parrot, all while enjoying a delicious, chewy treat. And that, he thought, was a pretty good life indeed.
