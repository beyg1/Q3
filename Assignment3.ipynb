# %% [markdown]
# <a href="https://colab.research.google.com/github/beyg1/Q3/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is assignment 2 to cover the usage of gemini  api to get images as prompt in Google Colab.
# #Step by Step Guide
# 1.  Step 1: Install Required Libraries:
#       *     !pip install google-generativeai
# 2.  Step 2: Import Required Libraries:
#       *     import google.generativeai as genai
#       *     import PIL.Image   (For handling image inputs)
# 3.  Step 3: Set Up Your Gemini API Key:
#       *     Replace 'YOUR_API_KEY' with your actual API key from Google AI
#       *     genai.configure(api_key="YOUR_API_KEY")
# 4.  Step 4: Upload and Load an Image:
#       *    Use Colab's file upload feature to upload an image.
#       *    Load the image using the PIL library.
# *      ![Screenshot 2024-12-17 171412.png](data:image/png;base64,...)
# 5.    Step 5: Send the Image as a Prompt to the Gemini Model:
# *    ![Screenshot 2024-12-17 171436.png](data:image/png;base64,...)
# 6. Step6: Test with a Custom Prompt
# * ![Screenshot 2024-12-17 171503.png](data:image/png;base64,...)

# %%
# Install the Google Generative AI library
# !pip install google-generativeai
import google.generativeai as genai

from google.colab import userdata
api_key = userdata.get('GOOGLE_API_KEY')




# Set up the API key (replace with your actual key)
genai.configure(api_key=api_key)


# Initialize Gemini Flash 2.0 model
model = genai.GenerativeModel('gemini-1.5-flash')

import PIL.Image
from google.colab import files

# Upload and load the image
uploaded = files.upload()
image_path = list(uploaded.keys())[0]
image = PIL.Image.open(image_path)
image.show()

# Send the image with a prompt
response = model.generate_content([image, "Just describe the image."])

# Print the response
print(response.text)
# Out:
# ...
#      <input type="file" id="files-6a3337d8-ce74-4da3-9934-9471ef05f14c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a3337d8-ce74-4da3-9934-9471ef05f14c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
